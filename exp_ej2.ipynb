# %%
from main import Model

# %%
from main import main
from dataset import normalize

def targetNormalize(target_data):
  data = target_data.copy()
  normalize(data)
  return data.to_numpy()

model = Model('./dataset/tp1_ej2_training.csv', (0, 8), (8, 10), targetNormalize)

# %%
errors = model.exp_2(
    [8, 8, 8, 2],
    500,
    0.01,
    (0, 400),
    (400, 500),
    5
)
# Out:
# S: [8, 8, 8, 2]
# Máxima #epocas: 500
# LR: 0.01
# B (mini-lotes): 5
# epoch: 100; error: 3.7723427005524783
# epoch: 200; error: 1.5095810062078048
# epoch: 300; error: 1.2011462056892355
# epoch: 400; error: 1.1385483478547833
# error cuadratico medio: 0.9511332456817316
